# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

# %% [markdown]
# ### Проверка статистических гипотез. P-значения. Доверительные интервалы. A/B-тестирование

# %% [markdown]
# 1. Известно, что генеральная совокупность распределена нормально со средним квадратическим отклонением, равным 16.
#
# Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95,
# если выборочная средняя M = 80, а объем выборки n = 256.

# %% [markdown]
# Доверительный интервал можно найти по формуле:
#
# $$ T_{1,2} = \bar{X} \pm \frac{s_0}{\sqrt{n}}\cdot c_{\gamma} $$
#
#
# Для того, чтобы найти среднеквадратическое отклонение выборки, при известном std генеральной совокупности
#
# $ s = \frac{16}{\sqrt{256}} = 1 $
#
# Так как размер выборки достаточно велик, за критическое значение возьмем 1.96
#
# А значит, доверительный интервал будет представлять из себя $(M-z_{crit}\cdot s;M+z_{crit}\cdot s)$ или
#
# $$ (78.04; 81.96) $$

# %% [markdown]
# ___

# %% [markdown]
# 2. В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью, получены опытные данные:
#
# 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1
# Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей,
# оценить истинное значение величины X при помощи доверительного интервала, покрывающего это
# значение с доверительной вероятностью 0,95.
#
# p. s. Задание из вебинара - больше 6.5

# %% [markdown]
# Гипотеза:
# $ H_0: M(x) = 6.5 $
# $ H_1: M(x) > 6.5 $
#
# $ \bar{x} = 6.59 $ - среднее выборки
# $ s = 0.428 $  - std выборки
# $ n = 10 $  - количество наблюдений
# $ v = 9 $  - количество степеней свободы
#
# Односторонний критерий:
#
# $ t_{v=9, crit=0.95} = 1.833 $
#
# $ t = \frac{6.59-6.5}{\frac{0.428}{3}} \approx 0.631 $
#
# $ t < t_{crit} $, следовательно мы не можем отвергнуть нулевую гипотезу

# %% [markdown]
# p.s. Для нахождения интервала, в которрый попадает истинное значение X с вероятностью 0.95 найдем граничные значения этой неизвестной
#
# $ (\frac{6.59-X}{\frac{0.428}{3}} = -1.833; \frac{6.59-X}{\frac{0.428}{3}} = 1.833) $
#
# $$ (6.33; 6.85) $$

# %% [markdown]
# ___

# %% [markdown]
# 3. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.
#
# Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр
# оказался равным 17.5 мм, а дисперсия известна и равна 4 мм.
#
# Гипотеза:
# $ H_0: M(x) = 17 $
# $ H_1: M(x) > 17 $
#
# $ n = 100 $
# $ \sigma_x^2 = 4 $
# $ \sigma = 2 $
# $ \bar{x} = 17.5 $
# $ \mu = 17 $
#
# Наблюдаемое значение критерия:
#
# $ U_{crit} = \frac{\bar{x}-\mu}{\sigma}\sqrt{n} = \frac{17.5-17}{2}\cdot 10 = 2.5 $
#
# По таблице критическое значение критерия будет равно 1.66
#
# Так как наблюдаемое значение критерия больше критического, то с вероятностью 0.95 отвергаем нулевую гипотезу

# %% [markdown]
# ___

# %% [markdown]
# 4. Продавец утверждает, что средний вес пачки печенья составляет 200 г.
#
# Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет:
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190.
# Известно, что их веса распределены нормально.
# Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?

# %% [markdown]
# Гипотеза:
# $ H_0: M(x) = 200 $
# $ H_1: M(x) \neq 200 $
#
#
# $$ t = \frac{\bar{x}-\mu}{\frac{s}{\sqrt{v}}} $$
#
# $ \mu = 200 $  - ожидаемое среднее
# $ \bar{x} = 198.5 $ - среднее выборки
# $ s = 4.225 $  - std выборки
# $ n = 10 $  - количество наблюдений
# $ v = n-1 = 9 $  - количество степеней свободы
#
# Так как у нас двусторонний тест, для 9 степеней свободы при доверительной вероятности 99% критическое значение будет равно:
#
# $ t_{v=9, crit=0.99} = 3.250 $
#
# Для того, чтобы отвергнуть нулевую гипотезу, необходимо, чтобы t выходило за пределы (-3.250, 3.250)
#
# Найдем t
#
# $ t = \frac{198.5-200}{\frac{4.225}{\sqrt{9}}} \approx -1.065 $
#
# Очевидно, что t не выходит за пределы интервала (-3.250, 3.250), а значит отвергнуть нулевую гипотезу мы не можем

# %%
print(stats.t.ppf(1-0.005, 9))
# Out:
# 3.2498355440153697
